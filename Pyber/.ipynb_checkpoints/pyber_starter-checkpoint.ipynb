# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_df = pd.read_csv("Resources/city_data.csv")
ride_df = pd.read_csv("Resources/ride_data.csv")

city_df.head()


ride_df.head()


# Read the City and Ride Data
#city_df.head()
# Combine the data into a single dataset
cityride_df = city_df.merge(ride_df)
# Display the data table for preview
cityride_df
# Out:
#                  city  driver_count   type                 date   fare  \
# 0         Richardfort            38  Urban  2018-02-24 08:40:38  13.93
# 1         Richardfort            38  Urban  2018-02-13 12:46:07  14.00
# 2         Richardfort            38  Urban  2018-02-16 13:52:19  17.92
# 3         Richardfort            38  Urban  2018-02-01 20:18:28  10.26
# 4         Richardfort            38  Urban  2018-04-17 02:26:37  23.00
# 5         Richardfort            38  Urban  2018-04-21 03:44:04   9.54
# 6         Richardfort            38  Urban  2018-02-03 00:14:26  29.04
# 7         Richardfort            38  Urban  2018-02-08 15:50:12  16.55
# 8         Richardfort            38  Urban  2018-04-03 15:07:34  40.77
# 9         Richardfort            38  Urban  2018-02-19 14:09:20  27.11
# 10        Richardfort            38  Urban  2018-04-22 03:06:56  39.74
# 11        Richardfort            38  Urban  2018-01-31 14:51:01  43.92
# 12        Richardfort            38  Urban  2018-03-04 22:13:57  14.83
# 13        Richardfort            38  Urban  2018-03-28 19:33:00   7.75
# 14        Richardfort            38  Urban  2018-02-14 03:27:28  44.11
# 15        Richardfort            38  Urban  2018-04-27 11:59:25  30.31
# 16        Richardfort            38  Urban  2018-03-03 11:57:24  11.42
# 17        Richardfort            38  Urban  2018-01-13 10:08:54  25.81
# 18        Richardfort            38  Urban  2018-03-06 12:53:05   8.28
# 19        Richardfort            38  Urban  2018-02-05 16:12:04  42.22
# 20        Richardfort            38  Urban  2018-04-04 15:04:56  16.35
# 21        Richardfort            38  Urban  2018-03-05 16:00:59   4.85
# 22        Richardfort            38  Urban  2018-04-14 11:56:28  43.01
# 23        Richardfort            38  Urban  2018-01-21 23:20:53  10.91
# 24        Richardfort            38  Urban  2018-03-16 23:00:51  21.39
# 25        Richardfort            38  Urban  2018-03-22 04:41:04  16.35
# 26        Richardfort            38  Urban  2018-01-03 01:06:17   5.32
# 27        Richardfort            38  Urban  2018-03-29 15:16:01  37.76
# 28       Williamsstad            59  Urban  2018-01-23 17:51:24  19.62
# 29       Williamsstad            59  Urban  2018-03-29 21:43:04  35.58
# ...               ...           ...    ...                  ...    ...
# 2345     Bradshawfurt             7  Rural  2018-03-24 18:53:18  57.51
# 2346     Bradshawfurt             7  Rural  2018-03-24 07:34:03  19.89
# 2347     Bradshawfurt             7  Rural  2018-02-18 22:21:26  34.32
# 2348     Bradshawfurt             7  Rural  2018-04-08 13:46:03  55.19
# 2349     Bradshawfurt             7  Rural  2018-04-07 21:12:49  49.70
# 2350     Bradshawfurt             7  Rural  2018-02-23 12:00:59  37.05
# 2351     Bradshawfurt             7  Rural  2018-04-10 09:47:54  19.07
# 2352     Bradshawfurt             7  Rural  2018-01-19 20:21:54  56.78
# 2353     Bradshawfurt             7  Rural  2018-01-30 10:55:23  51.39
# 2354     New Ryantown             2  Rural  2018-01-27 17:33:41  42.68
# 2355     New Ryantown             2  Rural  2018-04-18 19:43:54  42.97
# 2356     New Ryantown             2  Rural  2018-02-04 23:54:51  45.70
# 2357     New Ryantown             2  Rural  2018-04-30 01:50:44  50.81
# 2358     New Ryantown             2  Rural  2018-04-05 21:38:18  50.98
# 2359     New Ryantown             2  Rural  2018-05-05 19:29:38  26.53
# 2360   Randallchester             9  Rural  2018-04-13 11:13:31  43.22
# 2361   Randallchester             9  Rural  2018-02-19 03:52:47  58.55
# 2362   Randallchester             9  Rural  2018-02-11 05:42:29  25.78
# 2363   Randallchester             9  Rural  2018-03-25 13:36:46  10.37
# 2364   Randallchester             9  Rural  2018-04-07 23:42:07  10.79
# 2365      Jessicaport             1  Rural  2018-01-01 09:45:36  43.69
# 2366      Jessicaport             1  Rural  2018-01-14 07:09:17  18.05
# 2367      Jessicaport             1  Rural  2018-04-13 16:08:11  39.89
# 2368      Jessicaport             1  Rural  2018-03-18 16:59:40  33.72
# 2369      Jessicaport             1  Rural  2018-05-01 08:14:47  22.44
# 2370      Jessicaport             1  Rural  2018-01-31 17:57:25  58.29
# 2371  South Saramouth             7  Rural  2018-02-20 16:32:36  44.29
# 2372  South Saramouth             7  Rural  2018-01-28 15:55:33  31.25
# 2373  South Saramouth             7  Rural  2018-03-27 21:07:16  11.87
# 2374  South Saramouth             7  Rural  2018-04-12 18:11:50  57.23
#
#             ride_id
# 0     5628545007794
# 1      910050116494
# 2      820639054416
# 3     9554935945413
# 4      720020655850
# 5     3698147103219
# 6     4982665519010
# 7     2270463070874
# 8     9496210735824
# 9     8690324801449
# 10    4081388893008
# 11    4066949857460
# 12    9474112834050
# 13    5539056178883
# 14    2503858662225
# 15    6106446829435
# 16    2916078036620
# 17    9110913538598
# 18    5127600643309
# 19    4051093040264
# 20    6077906760851
# 21    3291539624738
# 22    7636011510547
# 23    3567611375530
# 24     237473464569
# 25    5934239154720
# 26    3268844473610
# 27    4802688422688
# 28     125986195523
# 29    4747780858464
# ...             ...
# 2345  2301998876294
# 2346  7867402022145
# 2347  8881996813087
# 2348  1742954306812
# 2349  5088814323688
# 2350  2068423024643
# 2351   739305106253
# 2352  1253403506597
# 2353  1328274868072
# 2354  7994603753131
# 2355   230914178346
# 2356  3570428225530
# 2357  5357550405010
# 2358  4834855490008
# 2359  2302209966018
# 2360  1076079536213
# 2361  8004803682564
# 2362  9010611749008
# 2363  3216382725494
# 2364  1615474447641
# 2365  2424875833354
# 2366  5405362355006
# 2367  6511242590852
# 2368  3046889917159
# 2369  3725278487786
# 2370   623154556195
# 2371  3622365199969
# 2372  7118046558393
# 2373   170351888128
# 2374  5081198789583
#
# [2375 rows x 6 columns]

# %%
 cityride_df["type"].value_counts()
# Out:
# Urban       1625
# Suburban     625
# Rural        125
# Name: type, dtype: int64

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types
x = np.arange(len(cityride_df))
y = cityride_df["type"]
s = cityride_df["fare"]

# Build the scatter plots for each city types
plt.scatter(x = x, y = s, s = y)

# Incorporate the other graph properties
# plt.""
# plt.title()
# plt.xlabel()
# plt.ylabel()
# plt.grid()


# Create a legend
# plt.legend(handles=[], loc="best")


# Incorporate a text label regarding circle size

# Save Figure
# plt.savefig("bubbleplot.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-7774c7b5ee17> in <module>
#       5
#       6 # Build the scatter plots for each city types
# ----> 7 plt.scatter(x = x, y = s, s = y)
#       8
#       9 # Incorporate the other graph properties
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2862         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2863         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2864         is not None else {}), **kwargs)
#    2865     sci(__ret)
#    2866     return __ret
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4295                 offsets=offsets,
#    4296                 transOffset=kwargs.pop('transform', self.transData),
# -> 4297                 alpha=alpha
#    4298                 )
#    4299         collection.set_transform(mtransforms.IdentityTransform())
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\collections.py in __init__(self, paths, sizes, **kwargs)
#     899         Collection.__init__(self, **kwargs)
#     900         self.set_paths(paths)
# --> 901         self.set_sizes(sizes)
#     902         self.stale = True
#     903
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\collections.py in set_sizes(self, sizes, dpi)
#     872             self._sizes = np.asarray(sizes)
#     873             self._transforms = np.zeros((len(self._sizes), 3, 3))
# --> 874             scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
#     875             self._transforms[:, 0, 0] = scale
#     876             self._transforms[:, 1, 1] = scale
#
# AttributeError: 'str' object has no attribute 'sqrt'

# %% [markdown]
# ## Total Fares by City Type

# %%
urbanfare = cityride_df["fare"][cityride_df["type"] == "Urban"].sum()
subfare = cityride_df["fare"][cityride_df["type"] == "Suburban"].sum()
ruralfare = cityride_df["fare"][cityride_df["type"] == "Rural"].sum()

wedges = [urbanfare,subfare,ruralfare]
colors = ["lightskyblue","lightcoral","gold"]
labels = ["Urban","Suburban","Rural"]
explode = [0.03,0.05,0.05]

plt.pie(wedges,
        labels = labels,
        colors = colors,
        autopct = '%1.1f%%',
       explode = explode,
       shadow = True,
       startangle = 44)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a991cbef28>,
#   <matplotlib.patches.Wedge at 0x1a990aa2908>,
#   <matplotlib.patches.Wedge at 0x1a991cc32e8>],
#  [Text(-1.039431852643898, 0.4432622516177916, 'Urban'),
#   Text(0.9379041352500448, -0.6654591145073195, 'Suburban'),
#   Text(0.9780180593238154, 0.6049633671855497, 'Rural')],
#  [Text(-0.5795062541288988, 0.24712851196390145, '62.7%'),
#   Text(0.5301197286195904, -0.37612906472152835, '30.5%'),
#   Text(0.5527928161395478, 0.3419358162353106, '6.8%')])

# %% [markdown]
# ## Total Rides by City Type

# %%
colors = ["lightskyblue","lightcoral","gold"]
labels = ["Urban","Suburban","Rural"]
explode = [0.03,0.05,0.05]

plt.pie(cityride_df["type"].value_counts(),
        labels = labels,
        colors = colors,
        autopct = '%1.1f%%',
       explode = explode,
       shadow = True,
       startangle = 24)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a991cfb2e8>,
#   <matplotlib.patches.Wedge at 0x1a991cfbc88>,
#   <matplotlib.patches.Wedge at 0x1a991da4668>],
#  [Text(-0.94939019014437, 0.612828089155219, 'Urban'),
#   Text(0.8503625230678357, -0.7741986691810473, 'Suburban'),
#   Text(1.1132373801984106, 0.2884484968395215, 'Rural')],
#  [Text(-0.5293060352132327, 0.34166521784759996, '68.4%'),
#   Text(0.48063968695138526, -0.43759055214580933, '26.3%'),
#   Text(0.629221127938232, 0.16303610690929476, '5.3%')])

# %% [markdown]
# ## Total Drivers by City Type

# %%
cityname = cityride_df.groupby(["city","type"]).mean()
cityname = cityname.reset_index()
cityname
# Out:
#                      city      type  driver_count       fare       ride_id
# 0             Amandaburgh     Urban          12.0  24.641667  5.359336e+12
# 1             Barajasview     Urban          26.0  25.332273  4.676968e+12
# 2           Barronchester  Suburban          11.0  36.422500  4.460796e+12
# 3             Bethanyland  Suburban          22.0  32.956111  5.842550e+12
# 4            Bradshawfurt     Rural           7.0  40.064000  3.735294e+12
# 5             Brandonfort  Suburban          10.0  35.437368  5.429539e+12
# 6             Carriemouth     Urban          52.0  28.314444  5.184855e+12
# 7         Christopherfurt     Urban          41.0  24.501852  4.582307e+12
# 8             Colemanland  Suburban          23.0  30.894545  5.155714e+12
# 9               Davidfurt  Suburban          23.0  31.995882  4.575051e+12
# 10              Deanville     Urban          49.0  25.842632  4.901508e+12
# 11         East Aaronbury  Suburban           7.0  25.661111  6.320489e+12
# 12        East Danielview  Suburban          22.0  31.560588  3.845422e+12
# 13        East Kaylahaven     Urban          65.0  23.757931  4.624814e+12
# 14          East Kentstad  Suburban          20.0  29.823077  4.482674e+12
# 15         East Marymouth  Suburban           5.0  30.835185  5.950071e+12
# 16              Erikaland     Urban          37.0  24.906667  4.483433e+12
# 17              Garzaport     Rural           7.0  24.123333  5.949150e+12
# 18            Grahamburgh     Urban          61.0  25.221200  4.162242e+12
# 19              Grayville  Suburban           2.0  27.763333  5.661291e+12
# 20         Harringtonfort     Rural           4.0  33.470000  5.726406e+12
# 21            Huntermouth     Urban          37.0  28.993750  4.280488e+12
# 22            Hurleymouth     Urban          36.0  25.891429  5.650851e+12
# 23               Jerryton     Urban          64.0  25.649200  4.955272e+12
# 24            Jessicaport     Rural           1.0  36.013333  3.622801e+12
# 25                Johnton     Urban          27.0  26.785714  5.294555e+12
# 26           Joneschester     Urban          39.0  22.289600  4.271941e+12
# 27             Josephside  Suburban          25.0  32.858148  4.479472e+12
# 28             Justinberg     Urban          39.0  23.694333  4.338578e+12
# 29              Karenberg     Urban          22.0  26.340000  5.685962e+12
# ..                    ...       ...           ...        ...           ...
# 90          South Evanton     Urban          11.0  26.726129  5.025553e+12
# 91             South Jack     Urban          46.0  22.965263  4.892221e+12
# 92         South Jennifer     Rural           7.0  35.264286  4.956215e+12
# 93        South Karenland     Urban           4.0  26.535526  5.067028e+12
# 94           South Latoya     Urban          10.0  20.093158  4.387006e+12
# 95      South Marychester     Rural           1.0  41.870000  3.498697e+12
# 96     South Michelleport     Urban          72.0  24.451613  4.727560e+12
# 97          South Phillip     Urban          38.0  28.571290  5.247892e+12
# 98        South Saramouth     Rural           7.0  36.160000  3.997991e+12
# 99           South Teresa  Suburban          21.0  31.220455  5.522500e+12
# 100           Taylorhaven     Rural           1.0  42.263333  6.493622e+12
# 101          Valentineton     Urban          45.0  24.636364  5.051062e+12
# 102          Veronicaberg  Suburban          20.0  32.828235  5.124262e+12
# 103          Victoriaport  Suburban          16.0  27.780000  4.875376e+12
# 104           West Angela     Urban          48.0  25.990000  4.842164e+12
# 105          West Anthony     Urban          70.0  24.736667  4.694461e+12
# 106  West Christopherberg     Urban          32.0  24.421154  4.637528e+12
# 107         West Ericstad     Urban          25.0  22.347222  5.101687e+12
# 108          West Gabriel     Urban          57.0  20.346087  5.573151e+12
# 109           West Hannah  Suburban          12.0  29.547619  4.611125e+12
# 110          West Heather     Rural           4.0  33.890000  5.237415e+12
# 111            West Heidi     Urban          28.0  23.133929  5.141304e+12
# 112       West Josephberg     Urban          45.0  21.720385  4.560076e+12
# 113         West Kimmouth  Suburban           4.0  29.871500  4.965593e+12
# 114   West Patrickchester     Urban          25.0  28.233125  5.302508e+12
# 115           West Robert     Urban          39.0  25.123871  4.575476e+12
# 116      West Samuelburgh     Urban          73.0  21.767600  4.566740e+12
# 117       Williamsonville  Suburban           2.0  31.875000  5.079952e+12
# 118          Williamsstad     Urban          59.0  24.362174  4.316939e+12
# 119          Williamsview     Urban          46.0  26.599000  4.537662e+12
#
# [120 rows x 5 columns]

# %%
urbandriver = cityname["driver_count"][cityname["type"] == "urban"].sum()
subdriver = cityname["driver_count"][cityname["type"] == "Suburban"].sum()
ruraldriver = cityname["driver_count"][cityname["type"] == "Rural"].sum()

wedges = [urbandriver,subdriver,ruraldriver]
colors = ["lightskyblue","lightcoral","gold"]
labels = ["Urban","Suburban","Rural"]
explode = [0.05,0.1,0.2]

plt.pie(wedges,
        labels = labels,
        colors = colors,
        autopct = '%1.1f%%',
       explode = explode,
       shadow = True,
       startangle = 318)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a9921ccfd0>,
#   <matplotlib.patches.Wedge at 0x1a9921c5668>,
#   <matplotlib.patches.Wedge at 0x1a9921bf390>],
#  [Text(0.8546165492990028, -0.7695001973126877, 'Urban'),
#   Text(-0.4743024682336262, 1.102287244155302, 'Suburban'),
#   Text(0.5138277857236366, -1.1941444663935536, 'Rural')],
#  [Text(0.48304413656030587, -0.4349348941332582, '0.0%'),
#   Text(-0.27667643980294854, 0.6430008924239261, '86.3%'),
#   Text(0.31620171429146865, -0.7348581331652637, '13.7%')])
